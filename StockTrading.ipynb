# %%
import oandapyV20
from oandapyV20 import API 
import oandapyV20.endpoints.instruments as instruments
import numpy as np
import pandas as pd
import random
import requests
from datetime import timedelta
import v20
#import ta
import math
import talib
#from talib import MA_Type
#from talib import TSF
#from talib import ADX
#from talib import MIDPRICE
#from talib import MIDPOINT
#from talib import TEMA
from talib import *
#from talib import penetration
from talib import CDLMORNINGSTAR,CDLONNECK,CDLPIERCING,CDLRICKSHAWMAN,CDLRISEFALL3METHODS,CDLSEPARATINGLINES,CDLSHOOTINGSTAR,CDLSHORTLINE,CDLSPINNINGTOP,CDLSTALLEDPATTERN,CDLSTICKSANDWICH,CDLTAKURI,CDLTRISTAR,CDLXSIDEGAP3METHODS,CDLUPSIDEGAP2CROWS,CDLUNIQUE3RIVER,CDLTHRUSTING,CDLTASUKIGAP,CDLMORNINGDOJISTAR,CDLMATHOLD,CDLMATCHINGLOW,CDLMARUBOZU,CDLLONGLINE,CDLLONGLEGGEDDOJI,CDLLADDERBOTTOM,CDLKICKINGBYLENGTH,CDLKICKING,CDLINVERTEDHAMMER,CDLINNECK,CDLIDENTICAL3CROWS,CDLHOMINGPIGEON,CDLHIKKAKEMOD,CDLHIKKAKE,CDLHIGHWAVE,CDLHARAMICROSS,CDLHARAMI,CDLHANGINGMAN,CDLHAMMER,CDLGRAVESTONEDOJI,CDLGAPSIDESIDEWHITE,CDLEVENINGSTAR,CDLEVENINGDOJISTAR,CDL2CROWS, CDL3BLACKCROWS,CDL3INSIDE,CDL3LINESTRIKE, CDL3OUTSIDE, CDL3STARSINSOUTH, CDL3WHITESOLDIERS,CDLABANDONEDBABY, CDLADVANCEBLOCK, CDLBELTHOLD, CDLBREAKAWAY,CDLCLOSINGMARUBOZU,CDLCONCEALBABYSWALL,CDLCOUNTERATTACK,CDLDARKCLOUDCOVER,CDLDOJI,CDLDOJISTAR,CDLDRAGONFLYDOJI,CDLENGULFING      

import matplotlib.pyplot as plt
import mplfinance as mpf
import matplotlib.ticker as mticker

import statsmodels.api as sm
import statsmodels.formula.api as smf


import matplotlib.dates as mpl_dates

plt.style.use('ggplot')
# %matplotlib inline

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
#######################  GLOBALS

stock_name = ''

# %%
def Get_Api_Key():
    access_token = 'd5698e5908e8b7989f50c40bac0f1c53-6fbc07c1ea7dad76a287069fb4f931e5'
    return access_token

def Get_AccountId():
    accountID = '101-001-14704433-001'
    return accountID

def Get_Account_Info():
    accountID = '101-001-14704433-001'
    access_token = 'd5698e5908e8b7989f50c40bac0f1c53-6fbc07c1ea7dad76a287069fb4f931e5'
    client = oandapyV20.API(access_token=access_token)
    return client

# %%
def  Currency_Pairs():
    pairs = ['EUR_USD', 'EUR_CHF', 'EUR_GBP', 'EUR_JPY', 'EUR_AUD', 'USD_CAD', 'USD_CHF', 'USD_JPY', 'USD_MXN', 'GBP_CHF', 'GBP_JPY', 'GBP_USD', 'AUD_JPY', 'AUD_USD', 'CHF_JPY', 'NZD_JPY', 'NZD_USD', 'XAU_USD', 'EUR_CAD', 'AUD_CAD', 'CAD_JPY', 'EUR_NZD', 'GRX_EUR', 'NZD_CAD', 'SGD_JPY', 'USD_HKD', 'USD_NOK', 'USD_TRY', 'XAU_AUD', 'AUD_CHF', 'AUX_AUD', 'EUR_HUF', 'EUR_PLN', 'FRX_EUR', 'HKX_HKD', 'NZD_CHF', 'SPX_USD', 'USD_HUF', 'USD_PLN', 'USD_ZAR', 'XAU_CHF', 'ZAR_JPY', 'BCO_USD', 'ETX_EUR', 'CAD_CHF', 'EUR_DKK', 'EUR_NOK', 'EUR_TRY', 'GBP_CAD', 'NSX_USD', 'UKX_GBP', 'USD_DKK', 'USD_SGD', 'XAG_USD', 'XAU_GBP', 'EUR_CZK', 'EUR_SEK', 'GBP_AUD', 'GBP_NZD', 'JPX_JPY', 'UDX_USD', 'USD_CZK', 'USD_SEK', 'WTI_USD', 'XAU_EUR', 'AUD_NZD']
    stock = random.sample(pairs,1)
    return stock

# %%
def Format_Patterns(df):
    P01 = Two_Crows(df)
    P02 = Three_Black_Crows(df)
    P03 = Three_Inside_Up_Down(df)
    P04 = Three_Line_Strike(df)
    P05 = Three_Outside_Up_Down(df)
    P06 = Three_Stars_In_The_South(df)
    P07 = Three_Advancing_White_Soldiers(df)
    P08 = Abandoned_Baby(df)
    P09 = Advance_Block(df)
    P10 = Belt_hold(df)
    P11 = Breakaway(df)
    P12 = Closing_Marubozu(df)
    P13 = Concealing_Baby_Swallow(df)
    P14 = Counter_Attack(df)
    P15 = Dark_Cloud_Cover(df)
    P16 = Doji(df)
    P17 = Doji_Star(df)
    P18 = Dragonfly_Doji(df)
    P19 = Engulfing_Pattern(df)
    P20 = Evening_Doji_Star(df)
    P21 = Evening_Star(df)
    P22 = Up_Down_gap_side_by_side_white_lines(df)
    P23 = Gravestone_Doji(df)
    P24 = Hammer(df)
    P25 = Hanging_Man(df)
    P26 = Harami_Pattern(df)
    P27 = Harami_Cross_Pattern(df)
    P28 = High_Wave_Candle(df)
    P29 = Hikkake_Pattern(df)
    P30 = Modified_Hikkake_Pattern(df)
    P31 = Homing_Pigeon(df)
    P32 = Identical_Three_Crows(df)
    P33 = In_Neck_Pattern(df)
    P34 = Inverted_Hammer(df)
    P35 = Kicking(df)   
    P36 = Kicking2(df)
    P37 = Ladder_Bottom(df)
    P38 = Long_Legged_Doji(df)
    P39 = Long_Line_Candle(df)
    P40 = Marubozu(df)
    P41 = Matching_Low(df) 
    P42 = Mat_Hold(df) 
    P43 = Morning_Doji_Star(df)
    P44 = Morning_Star(df)
    P45 = On_Neck_Pattern(df) 
    P46 = Piercing_Pattern(df) 
    P47 = Rickshaw_Man(df)
    P48 = Rising_Falling_Three_Methods(df)
    P49 = Separating_Lines(df)
    P50 = Shooting_Star(df)
    P51 = Short_Line_Candle(df)
    P52 = Spinning_Top(df)
    P53 = Stalled_Pattern(df)
    P54 = Stick_Sandwich(df)
    P55 = Takuri(df)
    P56 = Tasuki_Gap(df)
    P57 = Thrusting_Pattern(df)
    P58 = Tristar_Pattern(df)
    P59 = Unique_3_River(df)
    P60 = Upside_Gap_Two_Crows(df)
    P61 = Upside_Downside_Gap_Three_Methods(df)
   
   

    df2 = pd.concat([P01,P02,P03,P04,P05,P06,P07,P08,P09,P10,P11,P12,P13,P14,P15,P16,P17,P18,P19,P20,P21,P22,P23,P24,P25,P26,P27,P28,P29,P30,P31,P32,P33,P34,P35,P36,P37,P38,P39,P40,P41,P42,P43,P44,P45,P46,P47,P48,P49,P50,P51,P52,P53,P54,P55,P56,P57,P58,P59,P60,P61], axis=1)
    df2.columns = 'Two_Crows','Three_Black_Crows','Three_Inside_Up_Down','Three_Line_Strike','Three_Outside_Up_Down','Three_Stars_In_The_South','Three_Advancing_White_Soldiers','Abandoned_Baby','Advance_Block','Belt_hold','Breakaway','Closing_Marubozu','Concealing_Baby_Swallow','Counter_Attack','Dark_Cloud_Cover','Doji','Doji_Star','Dragonfly_Doji','Engulfing_Pattern','Evening_Doji_Star','Evening_Star','Up_Down_gap_side_by_side_white_lines','Gravestone_Doji','Hammer','Hanging_Man','Harami_Pattern','Harami_Cross_Pattern','High_Wave_Candle','Hikkake_Pattern','Modified_Hikkake_Pattern','Homing_Pigeon','Identical_Three_Crows','In_Neck_Pattern','Inverted_Hammer','Kicking', 'Kicking2','Ladder_Bottom','Long_Legged_Doji','Long_Line_Candle','Marubozu','Matching_Low','Mat_Hold','Morning_Doji_Star','Morning_Star','On_Neck_Pattern','Piercing_Pattern','Rickshaw_Man','Rising_Falling_Three_Methods','Separating_Lines','Shooting_Star','Short_Line_Candle','Spinning_Top','Stalled_Pattern','Stick_Sandwich','Takuri','Tasuki_Gap','Thrusting_Pattern','Tristar_Pattern','Unique_3_River','Upside_Gap_Two_Crows','Upside_Downside_Gap_Three_Methods'
    
    
    
    
    #df2['Two_Crows'],df2['Three_Black_Crows'],df2['Three_Inside_Up_Down'],df2['Three_Line_Strike'],df2['Three_Outside_Up_Down'],df2['Three_Stars_In_The_South'],df2['Three_Advancing_White_Soldiers'],df2['Abandoned_Baby'],df2['Advance_Block'],df2['Belt_hold'],df2['Breakaway'],df2['Closing_Marubozu'],df2['Concealing_Baby_Swallow'],df2['Counter_Attack'],df2['Dark_Cloud_Cover'],df2['Doji'],df2['Doji_Star'],df2['Dragonfly_Doji'],df2['Engulfing_Pattern'],df2['Evening_Doji_Star'],df2['Evening_Star'],df2['Up_Down_gap_side_by_side_white_lines'],df2['Gravestone_Doji'],df2['Hammer'],df2['Hanging_Man'],df2['Harami_Pattern'],df2['Harami_Cross_Pattern'],df2['High_Wave_Candle'],df2['Hikkake_Pattern'],df2['Modified_Hikkake_Pattern'],df2['Homing_Pigeon'],df2['Identical_Three_Crows'],df2['In_Neck_Pattern'],df2['Inverted_Hammer'],df2['Kicking'], df2['Kicking2'],df2['Ladder_Bottom'],df2['Long_Legged_Doji'],df2['Long_Line_Candle'],df2['Marubozu'],df2['Matching_Low'],df2['Mat_Hold'],df2['Morning_Doji_Star'],df2['Morning_Star'],df2['On_Neck_Pattern'],df2['Piercing_Pattern'],df2['Rickshaw_Man'],df2['Rising_Falling_Three_Methods'],df2['Separating_Lines'],df2['Shooting_Star'],df2['Short_Line_Candle'],df2['Spinning_Top'],df2['Stalled_Pattern'],df2['Stick_Sandwich'],df2['Takuri'],df2['Tasuki_Gap'],df2['Thrusting_Pattern'],df2['Tristar_Pattern'],df2['Unique_3_River'],df2['Upside_Gap_Two_Crows'],df2['Upside_Downside_Gap_Three_Methods'] = [P01,P02,P03,P04,P05,P06,P07,P08,P09,P10,P11,P12,P13,P14,P15,P16,P17,P18,P19,P20,P21,P22,P23,P24,P25,P26,P27,P28,P29,P30,P31,P32,P33,P34,P35,P36,P37,P38,P39,P40,P41,P42,P43,P44,P45,P46,P47,P48,P49,P50,P51,P52,P53,P54,P55,P56,P57,P58,P59,P60,P61]
    return df2

# %%
#MA100 = Calculate_100DayMovingAverage(data)
SiMA = calcSMA(df)
Bu,Bm,Bl = calcBOLBAND(df)
MoM5 = calcMoM5(df)
TSF14 = calcTSF14(df) 
ADX = calcADX(df)
MIDPRICE5 = calcMIDPRICE5(df)
MIDPRICE1 = calcMIDPRICE1(df)
MIDPRICE3 = calcMIDPRICE3(df)
TEMA = calcTEMA(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1075-8bddb9a662c9> in <module>()
#       1 #MA100 = Calculate_100DayMovingAverage(data)
# ----> 2 SiMA = calcSMA(df)
#       3 Bu,Bm,Bl = calcBOLBAND(df)
#       4 MoM5 = calcMoM5(df)
#       5 TSF14 = calcTSF14(df)
#
# <ipython-input-1066-ce63bfcbcc4d> in calcSMA(df)
#       7
#       8 def calcSMA(df):
# ----> 9     output = talib.SMA(closeB)
#      10     return output
#      11
#
# NameError: name 'closeB' is not defined

# %%
def Format_Data(data,SiMA,Bu,Bm,Bl,MoM5,TSF14,ADX,MIDPRICE5,MIDPRICE1,MIDPRICE3,TEMA):
    global stock_name   
    
    
    inc = 0
    dat = []
    for oo in data['candles']:
        dat.append([
        oo['time'], 
        oo['volume'], 
        oo['mid']['o'], 
        oo['mid']['h'], 
        oo['mid']['l'], 
        oo['mid']['c'],
        SiMA[inc],
        Bu[inc],
        Bm[inc],
        Bl[inc],
        MoM5[inc],
        TSF14[inc],
        ADX[inc],
        MIDPRICE5[inc],
        MIDPRICE1[inc],
        MIDPRICE3[inc],
        TEMA[inc],
        
            
        ])
        inc +=1
        #print(inc)
    df = pd.DataFrame(dat)
    df.columns = ['Time',
                  'Volume',
                  'Open',
                  'High',
                  'Low',
                  'Close'                                
                 
                 ]
    df['Time'] = pd.to_datetime(df['Time'])
    df['Time'] = df['Time'].dt.strftime('%Y-%m-%d %I:%M:%S')
    df['Time'] = pd.to_datetime(df['Time'])
    df = df.set_index('Time')
    #graph(df)
    

    #output = talib.SMA(df['Close'])
    #output2 = talib.MOM(df['Close'], timeperiod=5)
    #print(output)
    #print(output2)
    #pd.set_option('display.max_rows', 500)
    #pd.set_option('display.max_columns', 500)
    #pd.set_option('display.width', 1500)
    print(stock_name)
    #print(df)

    #graph(df)
    
    return df

# %%
def Make_Request():
    global stock_name
    client = Get_Account_Info()
    pair = Currency_Pairs()
    pair = pair[0]
    #print(pair,pair[0])
    #print(pair)

    params = {
        #"Accept-Datetime-Format":['unix','555.555'],   
        "count": 500,
        #"granularity":''
        }

    data = 'none'
    try:
        r = instruments.InstrumentsCandles(instrument=pair, params=params)
        data = client.request(r)
    except:
        print('That stock isnt supported')

    if data == 'none':
        Make_Request()
    elif data != 'none':
        inc = 0
        dat = []
        for oo in data['candles']:
            dat.append([
            oo['time'], 
            oo['volume'], 
            oo['mid']['o'], 
            oo['mid']['h'], 
            oo['mid']['l'], 
            oo['mid']['c']
            ])
            inc +=1
            
    df = pd.DataFrame(dat)
    df.columns = ['Time',
                  'Volume',
                  'Open',
                  'High',
                  'Low',
                  'Close',
                  'SiMA',
                  'BolUp',
                  'BolMid',
                  'BolLow',
                  'Momentum',
                  'TSF14',
                  'ADX',
                  'MIDPRICE5',
                  'MIDPRICE1',
                  'MIDPRICE3',
                  'TEMA'               
          
                 
                 
                 ]
    df['Time'] = pd.to_datetime(df['Time'])
    df['Time'] = df['Time'].dt.strftime('%Y-%m-%d %I:%M:%S')
    df['Time'] = pd.to_datetime(df['Time'])
    df = df.set_index('Time')

    stock_name = pair
    
    
    
    return df

# %%
#########################################  INDICATORS


def calcBOLBAND(df): 
    upper, middle, lower = talib.BBANDS(closeB, matype=MA_Type.T3)
    return upper,middle,lower

def calcSMA(df):
    output = talib.SMA(closeB)
    return output

def calcMoM5(df):
    MOM5 = talib.MOM(closeB, timeperiod=5)
    return MOM5
def calcTSF14(df):
    real = TSF(closeB, timeperiod=14)
    return real
def calcADX(df):
    real = ADX(highB, lowB, closeB, timeperiod=14)
    return real

def calcTEMA(df):
    real = TEMA(closeB, timeperiod=30)
    return real
    
def calcMIDPRICE5(df):
    real = MIDPRICE(highB, lowB, timeperiod=50)
    return real

def calcMIDPRICE1(df):
    real = MIDPRICE(highB, lowB, timeperiod=100)
    return real

def calcMIDPRICE3(df):
    real = MIDPRICE(highB, lowB, timeperiod=200)

    return real

# %%
def Two_Crows(df):
    #The upside gap two crows is viewed by chartists as a somewhat ominous pattern, since it potentially signals that the index or security may be rolling over as its upward move ends and a downtrend begins.
    integer = CDL2CROWS(df['Open'], df['High'], df['Low'], df['Close'])
    
    #print(integer)
    return integer

def Three_Black_Crows(df):
    #The bearish three black crows reversal pattern starts at or near the high of an uptrend, with three black bars posting lower lows that close near intrabar lows. This pattern predicts that the decline will continue to even lower lows, perhaps triggering a broader-scale downtrend. The most bearish version starts at a new high (point A on the chart) because it traps buyers entering momentum plays. According to Bulkowski, this pattern predicts lower prices with a 78% accuracy rate.4﻿
    integer = CDL3BLACKCROWS(df['Open'], df['High'], df['Low'], df['Close'])
    
    #print(integer)
    return integer

def Three_Inside_Up_Down(df):    
    integer = CDL3INSIDE(df['Open'], df['High'], df['Low'], df['Close'])
    
    #print(integer)
    return integer

def Three_Line_Strike(df):
    #According to Bulkowski, this reversal predicts higher prices with an 84% accuracy rate
    integer = CDL3LINESTRIKE(df['Open'], df['High'], df['Low'], df['Close'])
    
    #print(integer)
    return integer

def Three_Outside_Up_Down(df):
    #Three outside up/down are patterns of three candlesticks that often signal a reversal in trend.
    
    integer = CDL3OUTSIDE(df['Open'], df['High'], df['Low'], df['Close'])
    
    #print(integer)
    return integer

def Three_Stars_In_The_South(df):
    
    
    integer = CDL3STARSINSOUTH(df['Open'], df['High'], df['Low'], df['Close'])

    
    #print(integer)
    return integer

def Three_Advancing_White_Soldiers(df):
    
    
    integer = CDL3WHITESOLDIERS(df['Open'], df['High'], df['Low'], df['Close'])
    
    #print(integer)
    return integer


def Abandoned_Baby(df):
    #The bullish abandoned baby reversal pattern appears at the low of a downtrend, after a series of black candles print lower lows.8﻿ The market gaps lower on the next bar, but fresh sellers fail to appear, yielding a narrow range doji candlestick with opening and closing prints at the same price. A bullish gap on the third bar completes the pattern, which predicts that the recovery will continue to even higher highs, perhaps triggering a broader-scale uptrend. According to Bulkowski, this pattern predicts higher prices with a 70% accuracy rate.
    
    integer = CDLABANDONEDBABY(df['Open'], df['High'], df['Low'], df['Close'], penetration=0)
    
    #print(integer)
    return integer

def Advance_Block(df):
    
    
    integer = CDLADVANCEBLOCK(df['Open'], df['High'], df['Low'], df['Close'])
    
    #print(integer)
    return integer


def Belt_hold(df):
   
    
    integer = CDLBELTHOLD(df['Open'], df['High'], df['Low'], df['Close'])
    
    #print(integer)
    return integer

def Breakaway(df):
    
    
    integer = CDLBREAKAWAY(df['Open'], df['High'], df['Low'], df['Close'])
    
    #print(integer)
    return integer

def Closing_Marubozu(df):
    
    
    integer = CDLCLOSINGMARUBOZU(df['Open'], df['High'], df['Low'], df['Close'])
    
    #print(integer)
    return integer

def Concealing_Baby_Swallow(df):
    
    
    integer = CDLCONCEALBABYSWALL(df['Open'], df['High'], df['Low'], df['Close'])
    
    #print(integer)
    return integer

def Counter_Attack(df):
    
    
    integer = CDLCOUNTERATTACK(df['Open'], df['High'], df['Low'], df['Close'])
    
    #print(integer)
    return integer

def Dark_Cloud_Cover(df):
    
    
    integer = CDLDARKCLOUDCOVER(df['Open'], df['High'], df['Low'], df['Close'], penetration=0)
    
    #print(integer)
    return integer

def Doji(df):
    
    
    integer = CDLDOJI(df['Open'], df['High'], df['Low'], df['Close'])
    
    #print(integer)
    return integer

def Doji_Star(df):
    
    
    integer = CDLDOJISTAR(df['Open'], df['High'], df['Low'], df['Close'])
    
    #print(integer)
    return integer

def Dragonfly_Doji(df):
    
    integer = CDLDRAGONFLYDOJI(df['Open'], df['High'], df['Low'], df['Close'])
    
    #print(integer)
    return integer

def Engulfing_Pattern(df):
    
    integer = CDLENGULFING(df['Open'], df['High'], df['Low'], df['Close'])
    
    #print(integer)
    return integer



def Evening_Doji_Star(df):
    
    
    integer = CDLEVENINGDOJISTAR(df['Open'], df['High'], df['Low'], df['Close'], penetration=0)
    
    #print(integer)
    return integer


def Evening_Star(df):
    #The bearish evening star reversal pattern starts with a tall white bar that carries an uptrend to a new high.6
    #The market gaps higher on the next bar, but fresh buyers fail to appear, yielding a narrow range candlestick. A gap down on the third bar completes the pattern, which predicts that the decline will continue to even lower lows, perhaps triggering a broader-scale downtrend. According to Bulkowski, this pattern predicts lower prices with a 72% accuracy rate.7﻿
    
    integer = CDLEVENINGSTAR(df['Open'], df['High'], df['Low'], df['Close'], penetration=0)
    
    #print(integer)
    return integer

def Up_Down_gap_side_by_side_white_lines(df):
    
    
    integer = CDLGAPSIDESIDEWHITE(df['Open'], df['High'], df['Low'], df['Close'])
    
    #print(integer)
    return integer


def Gravestone_Doji(df):
    
    
    integer = CDLGRAVESTONEDOJI(df['Open'], df['High'], df['Low'], df['Close'])
    
    #print(integer)
    return integer 




def Hammer(df):
    
    
    integer = CDLHAMMER(df['Open'], df['High'], df['Low'], df['Close'])
    
    #print(integer)
    return integer 


def Hanging_Man(df):
    
    
    integer = CDLHANGINGMAN(df['Open'], df['High'], df['Low'], df['Close'])
    
    #print(integer)
    return integer


def Harami_Pattern(df):
    
    
    integer = CDLHARAMI(df['Open'], df['High'], df['Low'], df['Close'])
    
    #print(integer)
    return integer

def Harami_Cross_Pattern(df):
    
    
    integer = CDLHARAMICROSS(df['Open'], df['High'], df['Low'], df['Close'])
    
    #print(integer)
    return integer


def High_Wave_Candle(df):
    
    
    integer = CDLHIGHWAVE(df['Open'], df['High'], df['Low'], df['Close'])
    
    #print(integer)
    return integer


def Hikkake_Pattern(df):
    
    
    integer = CDLHIKKAKE(df['Open'], df['High'], df['Low'], df['Close'])
    
    #print(integer)
    return integer

def Modified_Hikkake_Pattern(df):
    
    integer = CDLHIKKAKEMOD(df['Open'], df['High'], df['Low'], df['Close'])
    
    #print(integer)
    return integer


def Homing_Pigeon(df):
    
    integer = CDLHOMINGPIGEON(df['Open'], df['High'], df['Low'], df['Close'])
    
    #print(integer)
    return integer


def Identical_Three_Crows(df):
    
    integer = CDLIDENTICAL3CROWS(df['Open'], df['High'], df['Low'], df['Close'])
    
    #print(integer)
    return integer

def In_Neck_Pattern(df):

    integer = CDLINNECK(df['Open'], df['High'], df['Low'], df['Close'])
    
    #print(integer)
    return integer
def Inverted_Hammer(df):
    
    

    integer = CDLINVERTEDHAMMER(df['Open'], df['High'], df['Low'], df['Close'])
    
    #print(integer)
    return integer
def Kicking(df):   
     

    integer = CDLKICKING(df['Open'], df['High'], df['Low'], df['Close'])
    
    #print(integer)
    return integer
def Kicking2(df):

    integer = CDLKICKINGBYLENGTH(df['Open'], df['High'], df['Low'], df['Close'])
    
    #print(integer)
    return integer
def Ladder_Bottom(df):
    
    integer = CDLLADDERBOTTOM(df['Open'], df['High'], df['Low'], df['Close'])
    
    #print(integer)
    return integer
def Long_Legged_Doji(df):

    integer = CDLLONGLEGGEDDOJI(df['Open'], df['High'], df['Low'], df['Close'])
    
    #print(integer)
    return integer
def Long_Line_Candle(df):
    

    integer = CDLLONGLINE(df['Open'], df['High'], df['Low'], df['Close'])
    
    #print(integer)
    return integer
def Marubozu(df):

    integer = CDLMARUBOZU(df['Open'], df['High'], df['Low'], df['Close'])
    
    #print(integer)
    return integer
def Matching_Low(df): 

    integer = CDLMATCHINGLOW(df['Open'], df['High'], df['Low'], df['Close'])
    
    #print(integer)
    return integer
def Mat_Hold(df): 

    integer = CDLMATHOLD(df['Open'], df['High'], df['Low'], df['Close'], penetration=0)
    
    #print(integer)
    return integer
def Morning_Doji_Star(df):

    integer = CDLMORNINGDOJISTAR(df['Open'], df['High'], df['Low'], df['Close'], penetration=0)
    
    #print(integer)
    return integer

def Morning_Star(df):

    integer = CDLMORNINGSTAR(df['Open'], df['High'], df['Low'], df['Close'], penetration=0)
    
    #print(integer)
    return integer


def On_Neck_Pattern(df): 

    integer = CDLONNECK(df['Open'], df['High'], df['Low'], df['Close']) 
    #print(integer)
    return integer


def Piercing_Pattern(df): 

    integer = CDLPIERCING(df['Open'], df['High'], df['Low'], df['Close'])
    #print(integer)
    return integer


def Rickshaw_Man(df):
 
    integer = CDLRICKSHAWMAN(df['Open'], df['High'], df['Low'], df['Close'])
    #print(integer)
    return integer


def Rising_Falling_Three_Methods(df):

    integer = CDLRISEFALL3METHODS(df['Open'], df['High'], df['Low'], df['Close'])
    #print(integer)
    return integer


def Separating_Lines(df):
 
    integer = CDLSEPARATINGLINES(df['Open'], df['High'], df['Low'], df['Close'])
    #print(integer)
    return integer


def Shooting_Star(df):
 
    integer = CDLSHOOTINGSTAR(df['Open'], df['High'], df['Low'], df['Close'])

    #print(integer)
    return integer

def Short_Line_Candle(df):

    integer = CDLSHORTLINE(df['Open'], df['High'], df['Low'], df['Close'])
    #print(integer)
    return integer


def Spinning_Top(df):
 
    integer = CDLSPINNINGTOP(df['Open'], df['High'], df['Low'], df['Close'])
    #print(integer)
    return integer


def Stalled_Pattern(df):

    integer = CDLSTALLEDPATTERN(df['Open'], df['High'], df['Low'], df['Close'])
    #print(integer)
    return integer


def Stick_Sandwich(df):

    integer = CDLSTICKSANDWICH(df['Open'], df['High'], df['Low'], df['Close'])    
    #print(integer)
    return integer


def Takuri(df):

    integer = CDLTAKURI(df['Open'], df['High'], df['Low'], df['Close'])
    #print(integer)
    return integer


def Tasuki_Gap(df):

    integer = CDLTASUKIGAP(df['Open'], df['High'], df['Low'], df['Close'])
    #print(integer)
    return integer
 

def Thrusting_Pattern(df):
    
    integer = CDLTHRUSTING(df['Open'], df['High'], df['Low'], df['Close'])
    #print(integer)
    return integer

def Tristar_Pattern(df):
 
    integer = CDLTRISTAR(df['Open'], df['High'], df['Low'], df['Close'])
    #print(integer)
    return integer

def Unique_3_River(df):
 
    integer = CDLUNIQUE3RIVER(df['Open'], df['High'], df['Low'], df['Close'])
    #print(integer)
    return integer

def Upside_Gap_Two_Crows(df):
 
    integer = CDLUPSIDEGAP2CROWS(df['Open'], df['High'], df['Low'], df['Close'])
    #print(integer)
    return integer

def Upside_Downside_Gap_Three_Methods(df):
     
    integer = CDLXSIDEGAP3METHODS(df['Open'], df['High'], df['Low'], df['Close'])
    #print(integer)
    return integer














#e bearish two black gapping continuation pattern appears after a notable top in an uptrend, with a gap down that yields two black bars posting lower lows.5﻿ This pattern predicts that the decline will continue to even lower lows, perhaps triggering a broader-scale downtrend. According to Bulkowski, this pattern predicts lower prices with a 68% accuracy rate.

#Two_Crows(df)
#Three_Black_Crows(df)
#Three_Inside_Up_Down(df)
#Three_Line_Strike(df)
#Three_Outside_Up_Down(df)
#Three_Stars_In_The_South(df)
#Three_Advancing_White_Soldiers(df)
#Abandoned_Baby(df)
#Advance_Block(df)
#Belt_hold(df)
#Breakaway(df)
#Closing_Marubozu(df)
#Concealing_Baby_Swallow(df)
#Counterattack(df)
#Dark_Cloud_Cover(df)
#Doji(df)
#Doji_Star(df)
#Dragonfly_Doji(df)
#Engulfing_Pattern(df)

# %%
def Graph(df,df2):
    
    df["SMA1"] = df['Close'].rolling(window=10).mean()
    df["SMA2"] = df['Close'].rolling(window=50).mean()
    df["SMA3"] = df['Close'].rolling(window=100).mean()
    
    
    fig,axes = plt.subplots(nrows=4,ncols=1,figsize=(30,12))
    fig = plt.figure(figsize=(8,2))
    ################################################################
    
    axes[0].plot(df['SMA1'], 'g--', label="SMA1")
    axes[0].plot(df['SMA2'], 'b--', label="SMA2")
    axes[0].plot(df['SMA3'], 'r--', label="SMA3")
    #axes[0].plot(df['Close'])
    #axes[0].plot(df)
    ################################################################
    
    axes[1].plot(df['BolUp'], 'g--', label="BUP")
    #axes[0].plot(df['BolMid'], 'o--', label="BMID")
    axes[1].plot(df['BolLow'], 'r--', label="BLOW")
   
    axes[1].plot(df['Close'], 'b', label="Close")
    axes[1].plot(df['SMA3'], 'o--', label="SMA3")
    
    ################################################################
    axes[2].plot(df['Volume'],label='Volume')
    axes[2].plot(df['ADX'],label='ADX')
    
    ###########################################################
    #axes[3]
    #axes[3].plot(df2['Two_Crows'], label='TwoCrows')
    axes[3].plot(df2['Three_Black_Crows'], label='ThreeBCrows')
    #axes[3].plot(df2['Three_Inside_Up_Down'], label='Three Inside Up/Down')
    axes[3].plot(df2['Three_Line_Strike'], label='ThreeLineStrike')
    #axes[3].plot(df2['Three_Outside_Up_Down'], label='Three Outside Up')
    #axes[3].plot(df2['Three_Stars_In_The_South'], label='Three Stars South')
    #axes[3].plot(df2['Three_Advancing_White_Soldiers'], label='Three Advancing White Soilders')
    axes[3].plot(df2['Abandoned_Baby'], label='Abandoned Baby')
    #axes[3].plot(df2['Advance_Block'], label='Advance Block')
    #axes[3].plot(df2['Belt_Hold'], label='Belt Hold')
    #axes[3].plot(df2['Breakaway'], label='Break Away')
    #axes[3].plot(df2['Closing_Marubozu'], label='Closing Marubozu')
    #axes[3].plot(df2['Concealing_Baby_Swallow'], label='Concealing Baby Swallow')
    axes[3].plot(df2['Counter_Attack'], label='Counter Attack')
    #axes[3].plot(df2['Dark_Cloud_Cover'], label='Dark Cloud Cover')
    axes[3].plot(df2['Doji'], label='Dojis')
    #axes[3].plot(df2['Doji_Star'], label='Doji Star')
    #axes[3].plot(df2['Dragonfly_Doji'], label='Dragon Fly Doji')
    #axes[3].plot(df2['Englufing_Pattern'], label='Englufing Pattern')
    #axes[3].plot(df2)
    
    axes[3].legend(loc=2)
    axes[2].legend(loc=2)
    axes[1].legend(loc=2)
    axes[0].legend(loc=2)
    plt.show()

# %%
def Flow():
    df = Make_Request()

    
    #df = Format_Data(data,SiMA,Bu,Bm,Bl,MoM5,TSF14,ADX,MIDPRICE5,MIDPRICE1,MIDPRICE3,TEMA)
    df2 = Format_Patterns(df)
    #print(df.head(100))

    return df,df2

# %%
df,df2 = Flow()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1074-d0bdf7c2beca> in <module>()
# ----> 1 df,df2 = Flow()
#
# <ipython-input-1071-1de1c058e391> in Flow()
#       1 def Flow():
# ----> 2     df = Make_Request()
#       3     #MA100 = Calculate_100DayMovingAverage(data)
#       4     SiMA = calcSMA(df)
#       5     Bu,Bm,Bl = calcBOLBAND(df)
#
# <ipython-input-1065-c5e5fb66a848> in Make_Request()
#      53                   'MIDPRICE1',
#      54                   'MIDPRICE3',
# ---> 55                   'TEMA'
#      56
#      57
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    3092         try:
#    3093             object.__getattribute__(self, name)
# -> 3094             return object.__setattr__(self, name, value)
#    3095         except AttributeError:
#    3096             pass
#
# ...

# %%
Graph(df,df2)
